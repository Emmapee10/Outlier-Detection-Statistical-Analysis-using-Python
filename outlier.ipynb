# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(4,2)
df=pd.read_csv("C:\\Users\\AKANINYENE EMMANUEL\\Downloads\\DATASCIENCECLASS\\weight-height.csv")
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df.sample(5)
# Out:
#       Gender     Height      Weight
# 1175    Male  72.124910  215.443401
# 1144    Male  69.582111  193.367198
# 313     Male  67.880559  175.222848
# 8524  Female  59.838569  106.358333
# 6771  Female  65.790395  119.670672

# %%
# students=[60,25,29,31,19,26,7,32,33,18,34,22,28,29,30,78]
num=np.array([2,3,4,5,6,7,8])
num.mean(), num.std()
# Out:
# (5.0, 2.0)

# %%
plt.hist(df.Height, bins=20, rwidth=0.9)
plt.xlabel('Height (inches)')
plt.ylabel('count')
plt.show()

# %%
df.Height.min()
# Out:
# 54.2631333250971

# %%
df.Height.max()
# Out:
# 78.9987423463896

# %%
from scipy.stats import norm
plt.hist(df.Height, bins=20, rwidth=0.9,density=True)
plt.xlabel('Height (inches)')
plt.ylabel('count')

rng=np.arange(df.Height.min(), df.Height.max(), 0.1)

plt.plot(rng,norm.pdf(rng, df.Height.mean(), df.Height.std()))

# %%
df.Height.mean()
# Out:
# 66.36755975482124

# %%
df.Height.std()
# Out:
# 3.8475281207732324

# %%
upper_limit=df.Height.mean() + 3*df.Height.std()
upper_limit
# Out:
# 77.91014411714094

# %%
lower_limit=df.Height.mean() - 3*df.Height.std()
lower_limit
# Out:
# 54.82497539250154

# %%
df_outlier=df[(df.Height>upper_limit)|(df.Height<lower_limit)]
df_outlier
# Out:
#       Gender     Height      Weight
# 994     Male  78.095867  255.690835
# 1317    Male  78.462053  227.342565
# 2014    Male  78.998742  269.989699
# 3285    Male  78.528210  253.889004
# 3757    Male  78.621374  245.733783
# 6624  Female  54.616858   71.393749
# 9285  Female  54.263133   64.700127

# %%
df_no_outlier=df[(df.Height<=upper_limit)&(df.Height>=lower_limit)]
df_no_outlier
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [9993 rows x 3 columns]

# %%
df_no_outlier.shape[0]
# Out:
# 9993

# %%
df_outlier.shape[0]
# Out:
# 7

# %% [raw]
# z-score

# %% [markdown]
# z-score

# %%
df['z_score']= (df.Height-df.Height.mean())/df.Height.std()

# %%
df
# Out:
#       Gender     Height      Weight   z_score
# 0       Male  73.847017  241.893563  1.943964
# 1       Male  68.781904  162.310473  0.627505
# 2       Male  74.110105  212.740856  2.012343
# 3       Male  71.730978  220.042470  1.393991
# 4       Male  69.881796  206.349801  0.913375
# ...      ...        ...         ...       ...
# 9995  Female  66.172652  136.777454 -0.050658
# 9996  Female  67.067155  170.867906  0.181830
# 9997  Female  63.867992  128.475319 -0.649655
# 9998  Female  69.034243  163.852461  0.693090
# 9999  Female  61.944246  113.649103 -1.149651
#
# [10000 rows x 4 columns]

# %%
df[df['z_score']>3]
# Out:
#      Gender     Height      Weight   z_score
# 994    Male  78.095867  255.690835  3.048271
# 1317   Male  78.462053  227.342565  3.143445
# 2014   Male  78.998742  269.989699  3.282934
# 3285   Male  78.528210  253.889004  3.160640
# 3757   Male  78.621374  245.733783  3.184854

# %%
df[df['z_score']<-3]
# Out:
#       Gender     Height     Weight   z_score
# 6624  Female  54.616858  71.393749 -3.054091
# 9285  Female  54.263133  64.700127 -3.146027

# %%
df_zcore_no_outlier=df[(df.z_score>-3)&(df.z_score<3)]
df_zcore_no_outlier
# Out:
#       Gender     Height      Weight   z_score
# 0       Male  73.847017  241.893563  1.943964
# 1       Male  68.781904  162.310473  0.627505
# 2       Male  74.110105  212.740856  2.012343
# 3       Male  71.730978  220.042470  1.393991
# 4       Male  69.881796  206.349801  0.913375
# ...      ...        ...         ...       ...
# 9995  Female  66.172652  136.777454 -0.050658
# 9996  Female  67.067155  170.867906  0.181830
# 9997  Female  63.867992  128.475319 -0.649655
# 9998  Female  69.034243  163.852461  0.693090
# 9999  Female  61.944246  113.649103 -1.149651
#
# [9993 rows x 4 columns]
